# %%
# Código para que los resultados no se corten
from IPython.display import Javascript
def resize_colab_cell():
  display(Javascript('google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'))
get_ipython().events.register('pre_run_cell', resize_colab_cell)

# %%
# conditional install TabNet
try:
  from pytorch_tabnet.tab_model import TabNetClassifier
except ModuleNotFoundError:
  if 'google.colab' in str(get_ipython()):
    # %pip install pytorch-tabnet

  from pytorch_tabnet.tab_model import TabNetClassifier
# Out:
# Collecting pytorch-tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.23.5)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.2.2)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.11.4)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (2.1.0+cu121)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (4.66.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->pytorch-tabnet) (1.3.0)
# Installing collected packages: pytorch-tabnet
# Successfully installed pytorch-tabnet-4.1.0

# %%
import random
import os
import numpy as np
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report,accuracy_score, balanced_accuracy_score, roc_auc_score, matthews_corrcoef, f1_score
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import StandardScaler
from pytorch_tabnet.metrics import Metric
from pytorch_tabnet.tab_model import TabNetClassifier
from pytorch_tabnet.augmentations import ClassificationSMOTE
import seaborn as sns

# %%
# Función para definir en un solo lugar todas las semillas
def seed_everything(seed_value):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    os.environ['PYTHONHASHSEED'] = str(seed_value)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

seed_value = 42
seed_everything(seed_value)

# %% [markdown]
# Leemos el archivo y seleccionamos las features

# %%
df = pd.read_csv('postprandial_hypoglycemias.csv')

selected_features = ['glucose','glucose_range','glucose_rate_change','mean_glucose_1h','glucose_1h','glucose_30m','cho', 'basal', 'bolus_normal', 'total_bolus_squared',
                'cob','next_iob','iob','aob_3h','aob_6h','hour']

target = 'hypoglycemia_severe'
df = df[selected_features + [target]]
df = df.dropna()
df = df.reset_index(drop=True)
X = df.drop(target, axis=1)
y = df[target]

# %% [markdown]
# Separamos los datos en grupos de entrenamiento, validación y test, procurando que todas tengan el mismo porcentaje de datos con hipoglicemia con stratify

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3)

# %%
print(f'Total de registros: {len(df)}')
print(f'Total de registros con hipoglicemia: {np.count_nonzero(y == 1)}')
print(f'Total de registros datos de entrenamiento: {len(y_train)}')
print(f'Total de registros datos de entrenamiento con hipoglicemia: {np.count_nonzero(y_train == 1)}')
print(f'Total de registros datos de test: {len(y_test)}')
print(f'Total de registros datos de test con hipoglicemia: {np.count_nonzero(y_test == 1)}')
# Out:
# Total de registros: 654
# Total de registros con hipoglicemia: 27
# Total de registros datos de entrenamiento: 457
# Total de registros datos de entrenamiento con hipoglicemia: 19
# Total de registros datos de test: 197
# Total de registros datos de test con hipoglicemia: 8

# %% [markdown]
# Calculamos los pesos de cada clase para pasar como parámetro al modelo

# %%
classes = np.unique(y_train)
class_weights = compute_class_weight('balanced', classes=classes, y=y_train)
class_weights_dict = dict(zip(classes, class_weights))
print(class_weights_dict)
# Out:
# {0: 0.521689497716895, 1: 12.026315789473685}

# %%
# Implementación de la métrica para F1 score
class F1Score(Metric):
    def __init__(self):
        self._name = "f1"
        self._maximize = True

    def __call__(self, y_true, y_score):
        y_pred = np.argmax(y_score, axis=1)

        return f1_score(y_true, y_pred)

# %%
# Implementación de la métrica para MCC
class MCC(Metric):
    def __init__(self):
        self._name = "MCC"
        self._maximize = True

    def __call__(self, y_true, y_score):
        y_pred = np.argmax(y_score, axis=1)

        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

        mcc_numerator = (tp * tn) - (fp * fn)
        mcc_denominator = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

        if mcc_denominator == 0:
            return 0
        else:
            return mcc_numerator / mcc_denominator

# %% [markdown]
# Entrenamiento del modelo en TabNet

# %%
evaluation_metrics = ['MCC','auc']
n_steps = 5
gamma = 1.3
patience = 50
epochs = 150
aug = ClassificationSMOTE(p=0.3)
batch_size = 64
virtual_batch_size = 8
classifier = TabNetClassifier(
                              verbose=1,
                              n_steps=n_steps,
                              gamma = gamma
                              )

classifier.fit(
               X_train=X_train.values, y_train=y_train,
               eval_set=[(X_train.values, y_train)],
               eval_name=['train'],
               batch_size=batch_size,
               virtual_batch_size=virtual_batch_size,
               patience=patience,
               max_epochs=epochs,
               weights=class_weights_dict,
               eval_metric= evaluation_metrics,
               augmentations=aug
               )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 1.07453 | train_MCC: 0.05743 | train_auc: 0.62004 |  0:00:02s
# epoch 1  | loss: 0.79463 | train_MCC: 0.05739 | train_auc: 0.57048 |  0:00:03s
# epoch 2  | loss: 0.68179 | train_MCC: 0.03333 | train_auc: 0.50541 |  0:00:04s
# epoch 3  | loss: 0.65727 | train_MCC: 0.1089  | train_auc: 0.69178 |  0:00:05s
# epoch 4  | loss: 0.62345 | train_MCC: 0.03086 | train_auc: 0.60406 |  0:00:06s
# epoch 5  | loss: 0.67038 | train_MCC: 0.12899 | train_auc: 0.63146 |  0:00:07s
# epoch 6  | loss: 0.65074 | train_MCC: 0.12177 | train_auc: 0.65958 |  0:00:08s
# epoch 7  | loss: 0.59954 | train_MCC: 0.07446 | train_auc: 0.62942 |  0:00:10s
# epoch 8  | loss: 0.61065 | train_MCC: 0.07013 | train_auc: 0.6645  |  0:00:11s
# epoch 9  | loss: 0.62865 | train_MCC: 0.12001 | train_auc: 0.65417 |  0:00:13s
# epoch 10 | loss: 0.59326 | train_MCC: 0.1503  | train_auc: 0.6931  |  0:00:15s
# epoch 11 | loss: 0.58656 | train_MCC: 0.08233 | train_auc: 0.70187 |  0:00:17s
# epoch 12 | loss: 0.60149 | train_MCC: 0.15949 | train_auc: 0.73937 |  0:00:18s
# epoch 13 | loss: 0.59841 | train_MCC: 0.196   | train_auc: 0.64864 |  0:00:20s
# epoch 14 | loss: 0.6503  | train_MCC: 0.0219  | train_auc: 0.64864 |  0:00:21s
# epoch 15 | loss: 0.61065 | train_MCC: 0.14727 | train_auc: 0.77938 |  0:00:22s
# epoch 16 | loss: 0.60048 | train_MCC: 0.11121 | train_auc: 0.71593 |  0:00:24s
# epoch 17 | loss: 0.55109 | train_MCC: 0.16322 | train_auc: 0.764   |  0:00:25s
# epoch 18 | loss: 0.62638 | train_MCC: 0.18512 | train_auc: 0.8123  |  0:00:27s
# epoch 19 | loss: 0.64355 | train_MCC: 0.15164 | train_auc: 0.73576 |  0:00:29s
# epoch 20 | loss: 0.62505 | train_MCC: 0.12759 | train_auc: 0.73804 |  0:00:30s
# epoch 21 | loss: 0.59489 | train_MCC: 0.13643 | train_auc: 0.73047 |  0:00:30s
# epoch 22 | loss: 0.57957 | train_MCC: 0.18772 | train_auc: 0.77349 |  0:00:31s
# epoch 23 | loss: 0.56176 | train_MCC: 0.17167 | train_auc: 0.78419 |  0:00:32s
# epoch 24 | loss: 0.57841 | train_MCC: 0.16865 | train_auc: 0.78467 |  0:00:32s
# epoch 25 | loss: 0.61362 | train_MCC: 0.16479 | train_auc: 0.72891 |  0:00:33s
# epoch 26 | loss: 0.57854 | train_MCC: 0.13915 | train_auc: 0.79392 |  0:00:33s
# epoch 27 | loss: 0.58766 | train_MCC: 0.24448 | train_auc: 0.81615 |  0:00:34s
# epoch 28 | loss: 0.58342 | train_MCC: 0.18891 | train_auc: 0.767   |  0:00:34s
# epoch 29 | loss: 0.57883 | train_MCC: 0.21082 | train_auc: 0.77686 |  0:00:35s
# epoch 30 | loss: 0.57622 | train_MCC: 0.18134 | train_auc: 0.81435 |  0:00:36s
# epoch 31 | loss: 0.55118 | train_MCC: 0.22349 | train_auc: 0.83778 |  0:00:36s
# epoch 32 | loss: 0.56992 | train_MCC: 0.29236 | train_auc: 0.82733 |  0:00:37s
# epoch 33 | loss: 0.5875  | train_MCC: 0.2672  | train_auc: 0.80041 |  0:00:37s
# epoch 34 | loss: 0.50454 | train_MCC: 0.30162 | train_auc: 0.83201 |  0:00:38s
# epoch 35 | loss: 0.52148 | train_MCC: 0.25905 | train_auc: 0.85665 |  0:00:38s
# epoch 36 | loss: 0.48889 | train_MCC: 0.29401 | train_auc: 0.87046 |  0:00:39s
# epoch 37 | loss: 0.56156 | train_MCC: 0.293   | train_auc: 0.87984 |  0:00:40s
# epoch 38 | loss: 0.51559 | train_MCC: 0.22047 | train_auc: 0.85076 |  0:00:41s
# epoch 39 | loss: 0.53445 | train_MCC: 0.30603 | train_auc: 0.88825 |  0:00:42s
# epoch 40 | loss: 0.50313 | train_MCC: 0.2765  | train_auc: 0.87143 |  0:00:42s
# epoch 41 | loss: 0.51448 | train_MCC: 0.21747 | train_auc: 0.83682 |  0:00:43s
# epoch 42 | loss: 0.62033 | train_MCC: 0.20735 | train_auc: 0.83994 |  0:00:43s
# epoch 43 | loss: 0.52404 | train_MCC: 0.2467  | train_auc: 0.86422 |  0:00:44s
# epoch 44 | loss: 0.52197 | train_MCC: 0.21338 | train_auc: 0.82216 |  0:00:44s
# epoch 45 | loss: 0.5277  | train_MCC: 0.18908 | train_auc: 0.84667 |  0:00:45s
# epoch 46 | loss: 0.56276 | train_MCC: 0.22165 | train_auc: 0.85388 |  0:00:46s
# epoch 47 | loss: 0.55603 | train_MCC: 0.20296 | train_auc: 0.83369 |  0:00:46s
# epoch 48 | loss: 0.60901 | train_MCC: 0.2552  | train_auc: 0.84715 |  0:00:47s
# epoch 49 | loss: 0.56186 | train_MCC: 0.21492 | train_auc: 0.851   |  0:00:47s
# epoch 50 | loss: 0.58453 | train_MCC: 0.20859 | train_auc: 0.83345 |  0:00:48s
# epoch 51 | loss: 0.5771  | train_MCC: 0.21094 | train_auc: 0.83021 |  0:00:48s
# epoch 52 | loss: 0.55179 | train_MCC: 0.19061 | train_auc: 0.83297 |  0:00:49s
# epoch 53 | loss: 0.50595 | train_MCC: 0.23268 | train_auc: 0.85376 |  0:00:50s
# epoch 54 | loss: 0.51466 | train_MCC: 0.22893 | train_auc: 0.84211 |  0:00:50s
# epoch 55 | loss: 0.49465 | train_MCC: 0.21464 | train_auc: 0.85713 |  0:00:51s
# epoch 56 | loss: 0.53199 | train_MCC: 0.25112 | train_auc: 0.8659  |  0:00:51s
# epoch 57 | loss: 0.51313 | train_MCC: 0.25283 | train_auc: 0.87599 |  0:00:52s
# epoch 58 | loss: 0.48375 | train_MCC: 0.22555 | train_auc: 0.86181 |  0:00:53s
# epoch 59 | loss: 0.47424 | train_MCC: 0.24914 | train_auc: 0.85508 |  0:00:54s
# epoch 60 | loss: 0.52881 | train_MCC: 0.26547 | train_auc: 0.86361 |  0:00:54s
# epoch 61 | loss: 0.54233 | train_MCC: 0.2511  | train_auc: 0.87299 |  0:00:55s
# epoch 62 | loss: 0.57202 | train_MCC: 0.30081 | train_auc: 0.8677  |  0:00:55s
# epoch 63 | loss: 0.51257 | train_MCC: 0.2427  | train_auc: 0.86662 |  0:00:56s
# epoch 64 | loss: 0.60499 | train_MCC: 0.24174 | train_auc: 0.8713  |  0:00:57s
# epoch 65 | loss: 0.54059 | train_MCC: 0.26335 | train_auc: 0.84463 |  0:00:57s
# epoch 66 | loss: 0.54222 | train_MCC: 0.26176 | train_auc: 0.87503 |  0:00:58s
# epoch 67 | loss: 0.48909 | train_MCC: 0.24042 | train_auc: 0.88272 |  0:00:58s
# epoch 68 | loss: 0.50567 | train_MCC: 0.25635 | train_auc: 0.89065 |  0:00:59s
# epoch 69 | loss: 0.49468 | train_MCC: 0.22116 | train_auc: 0.88056 |  0:00:59s
# epoch 70 | loss: 0.47569 | train_MCC: 0.23205 | train_auc: 0.88368 |  0:01:00s
# epoch 71 | loss: 0.48433 | train_MCC: 0.25635 | train_auc: 0.86722 |  0:01:00s
# epoch 72 | loss: 0.50987 | train_MCC: 0.2427  | train_auc: 0.8552  |  0:01:01s
# epoch 73 | loss: 0.51383 | train_MCC: 0.22612 | train_auc: 0.8665  |  0:01:02s
# epoch 74 | loss: 0.4969  | train_MCC: 0.32553 | train_auc: 0.90687 |  0:01:02s
# epoch 75 | loss: 0.51477 | train_MCC: 0.22405 | train_auc: 0.89017 |  0:01:03s
# epoch 76 | loss: 0.53439 | train_MCC: 0.22248 | train_auc: 0.8981  |  0:01:03s
# epoch 77 | loss: 0.54645 | train_MCC: 0.27319 | train_auc: 0.90531 |  0:01:04s
# epoch 78 | loss: 0.49925 | train_MCC: 0.26482 | train_auc: 0.91024 |  0:01:05s
# epoch 79 | loss: 0.49018 | train_MCC: 0.25841 | train_auc: 0.89149 |  0:01:05s
# epoch 80 | loss: 0.50065 | train_MCC: 0.24174 | train_auc: 0.89834 |  0:01:06s
# epoch 81 | loss: 0.49876 | train_MCC: 0.24503 | train_auc: 0.89882 |  0:01:07s
# epoch 82 | loss: 0.51969 | train_MCC: 0.30081 | train_auc: 0.89606 |  0:01:08s
# epoch 83 | loss: 0.52415 | train_MCC: 0.26735 | train_auc: 0.89041 |  0:01:08s
# epoch 84 | loss: 0.50331 | train_MCC: 0.25552 | train_auc: 0.88548 |  0:01:09s
# epoch 85 | loss: 0.50855 | train_MCC: 0.24657 | train_auc: 0.88861 |  0:01:09s
# epoch 86 | loss: 0.53549 | train_MCC: 0.26283 | train_auc: 0.88741 |  0:01:10s
# epoch 87 | loss: 0.50191 | train_MCC: 0.25254 | train_auc: 0.88981 |  0:01:10s
# epoch 88 | loss: 0.50785 | train_MCC: 0.28241 | train_auc: 0.90904 |  0:01:11s
# epoch 89 | loss: 0.45023 | train_MCC: 0.26619 | train_auc: 0.90783 |  0:01:12s
# epoch 90 | loss: 0.5027  | train_MCC: 0.26619 | train_auc: 0.90988 |  0:01:12s
# epoch 91 | loss: 0.48661 | train_MCC: 0.28499 | train_auc: 0.91613 |  0:01:13s
# epoch 92 | loss: 0.47536 | train_MCC: 0.24064 | train_auc: 0.90423 |  0:01:13s
# epoch 93 | loss: 0.46411 | train_MCC: 0.27176 | train_auc: 0.91637 |  0:01:14s
# epoch 94 | loss: 0.47817 | train_MCC: 0.28339 | train_auc: 0.9118  |  0:01:14s
# epoch 95 | loss: 0.51786 | train_MCC: 0.27899 | train_auc: 0.9148  |  0:01:15s
# epoch 96 | loss: 0.49991 | train_MCC: 0.24304 | train_auc: 0.9094  |  0:01:16s
# epoch 97 | loss: 0.49661 | train_MCC: 0.31623 | train_auc: 0.92298 |  0:01:16s
# epoch 98 | loss: 0.49816 | train_MCC: 0.26926 | train_auc: 0.90603 |  0:01:17s
# epoch 99 | loss: 0.50241 | train_MCC: 0.23771 | train_auc: 0.88032 |  0:01:17s
# epoch 100| loss: 0.48628 | train_MCC: 0.23142 | train_auc: 0.90002 |  0:01:18s
# epoch 101| loss: 0.43645 | train_MCC: 0.26232 | train_auc: 0.91709 |  0:01:19s
# epoch 102| loss: 0.49077 | train_MCC: 0.28153 | train_auc: 0.92069 |  0:01:20s
# epoch 103| loss: 0.42309 | train_MCC: 0.29378 | train_auc: 0.92862 |  0:01:20s
# epoch 104| loss: 0.46024 | train_MCC: 0.31484 | train_auc: 0.9261  |  0:01:21s
# epoch 105| loss: 0.50713 | train_MCC: 0.29279 | train_auc: 0.91997 |  0:01:22s
# epoch 106| loss: 0.45456 | train_MCC: 0.29378 | train_auc: 0.90603 |  0:01:22s
# epoch 107| loss: 0.46821 | train_MCC: 0.24503 | train_auc: 0.88488 |  0:01:23s
# epoch 108| loss: 0.49822 | train_MCC: 0.23945 | train_auc: 0.86349 |  0:01:23s
# epoch 109| loss: 0.53398 | train_MCC: 0.2797  | train_auc: 0.87371 |  0:01:24s
# epoch 110| loss: 0.5403  | train_MCC: 0.30106 | train_auc: 0.87972 |  0:01:24s
# epoch 111| loss: 0.4922  | train_MCC: 0.25409 | train_auc: 0.88897 |  0:01:25s
# epoch 112| loss: 0.52701 | train_MCC: 0.29557 | train_auc: 0.89858 |  0:01:26s
# epoch 113| loss: 0.45166 | train_MCC: 0.31864 | train_auc: 0.90807 |  0:01:26s
# epoch 114| loss: 0.46549 | train_MCC: 0.30552 | train_auc: 0.90988 |  0:01:27s
# epoch 115| loss: 0.49078 | train_MCC: 0.29025 | train_auc: 0.91132 |  0:01:27s
# epoch 116| loss: 0.46364 | train_MCC: 0.30672 | train_auc: 0.90603 |  0:01:28s
# epoch 117| loss: 0.48684 | train_MCC: 0.22032 | train_auc: 0.90531 |  0:01:28s
# epoch 118| loss: 0.47685 | train_MCC: 0.27176 | train_auc: 0.90675 |  0:01:29s
# epoch 119| loss: 0.48529 | train_MCC: 0.29921 | train_auc: 0.88801 |  0:01:30s
# epoch 120| loss: 0.50892 | train_MCC: 0.30106 | train_auc: 0.91661 |  0:01:30s
# epoch 121| loss: 0.52699 | train_MCC: 0.36545 | train_auc: 0.92406 |  0:01:31s
# epoch 122| loss: 0.48327 | train_MCC: 0.30672 | train_auc: 0.90639 |  0:01:32s
# epoch 123| loss: 0.50824 | train_MCC: 0.30432 | train_auc: 0.91817 |  0:01:33s
# epoch 124| loss: 0.45788 | train_MCC: 0.35505 | train_auc: 0.93067 |  0:01:33s
# epoch 125| loss: 0.51216 | train_MCC: 0.34903 | train_auc: 0.93043 |  0:01:34s
# epoch 126| loss: 0.46953 | train_MCC: 0.28347 | train_auc: 0.92442 |  0:01:34s
# epoch 127| loss: 0.46263 | train_MCC: 0.29439 | train_auc: 0.91937 |  0:01:35s
# epoch 128| loss: 0.45368 | train_MCC: 0.29764 | train_auc: 0.91757 |  0:01:36s
# epoch 129| loss: 0.45171 | train_MCC: 0.3095  | train_auc: 0.92093 |  0:01:36s
# epoch 130| loss: 0.49014 | train_MCC: 0.3106  | train_auc: 0.93223 |  0:01:37s
# epoch 131| loss: 0.45163 | train_MCC: 0.30292 | train_auc: 0.93031 |  0:01:37s
# epoch 132| loss: 0.46799 | train_MCC: 0.29738 | train_auc: 0.9297  |  0:01:38s
# epoch 133| loss: 0.49308 | train_MCC: 0.29928 | train_auc: 0.93463 |  0:01:38s
# epoch 134| loss: 0.38627 | train_MCC: 0.32604 | train_auc: 0.93331 |  0:01:39s
# epoch 135| loss: 0.47605 | train_MCC: 0.32797 | train_auc: 0.94436 |  0:01:40s
# epoch 136| loss: 0.44736 | train_MCC: 0.32681 | train_auc: 0.94388 |  0:01:40s
# epoch 137| loss: 0.42218 | train_MCC: 0.37215 | train_auc: 0.94761 |  0:01:41s
# epoch 138| loss: 0.43862 | train_MCC: 0.36945 | train_auc: 0.94076 |  0:01:41s
# epoch 139| loss: 0.4785  | train_MCC: 0.31304 | train_auc: 0.94196 |  0:01:42s
# epoch 140| loss: 0.41325 | train_MCC: 0.34131 | train_auc: 0.9446  |  0:01:43s
# epoch 141| loss: 0.43371 | train_MCC: 0.34321 | train_auc: 0.94533 |  0:01:43s
# epoch 142| loss: 0.48396 | train_MCC: 0.30432 | train_auc: 0.93223 |  0:01:44s
# epoch 143| loss: 0.43052 | train_MCC: 0.34707 | train_auc: 0.94424 |  0:01:45s
# epoch 144| loss: 0.49005 | train_MCC: 0.26686 | train_auc: 0.93944 |  0:01:46s
# epoch 145| loss: 0.45342 | train_MCC: 0.30095 | train_auc: 0.94893 |  0:01:46s
# epoch 146| loss: 0.43959 | train_MCC: 0.33033 | train_auc: 0.95025 |  0:01:47s
# epoch 147| loss: 0.50598 | train_MCC: 0.30246 | train_auc: 0.95302 |  0:01:47s
# epoch 148| loss: 0.42385 | train_MCC: 0.34903 | train_auc: 0.95121 |  0:01:48s
# epoch 149| loss: 0.44476 | train_MCC: 0.34707 | train_auc: 0.94364 |  0:01:49s
# Stop training because you reached max_epochs = 150 with best_epoch = 147 and best_train_auc = 0.95302
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %% [markdown]
# Métricas durante el entrenamiento

# %%
for metric in evaluation_metrics:
    plt.figure()
    plt.plot(classifier.history['train_' + metric], label='Train ' + metric)
    plt.title('Training and Validation ' + metric)
    plt.ylabel(metric)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %% [markdown]
# **Obtenemos las predicciones a partir del umbral indicado y los datos de test**

# %%
y_pred_probs = classifier.predict_proba(X_test.values)[:,1]
threshold = 0.5
y_pred = (y_pred_probs >= threshold).astype(int)

# %% [markdown]
# **Curva ROC**

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **Matriz de confusión**

# %%
cm = confusion_matrix(y_test, y_pred)

cm_df = pd.DataFrame(cm,
                     index = ['Non-Hypoglycemic', 'Hypoglycemic'],
                     columns = ['Non-Hypoglycemic', 'Hypoglycemic'])

plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %% [markdown]
# **Resumen métricas modelo TabNet**

# %%
tn, fp, fn, tp = cm.ravel()

sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

report = classification_report(y_test, y_pred, target_names=['Non-Hypoglycemic', 'Hypoglycemic'], output_dict=True)

f1Score = report['Hypoglycemic']['f1-score']

mcc = matthews_corrcoef(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
balanced_acuracy = balanced_accuracy_score(y_test, y_pred)

metrics = {
    'Accuracy': accuracy.round(2),
    'Sensitivity': sensitivity.round(2),
    'Specificity': specificity.round(2),
    'ROC AUC': roc_auc.round(2),
    'F1 Score (Hypoglycemia class)': round(f1Score,2),
    'MCC': mcc.round(2),
    'Balanced accuracy': balanced_acuracy,
    'Classification Report': report
}

metrics
# Out:
# {'Accuracy': 0.7,
#  'Sensitivity': 0.75,
#  'Specificity': 0.7,
#  'ROC AUC': 0.74,
#  'F1 Score (Hypoglycemia class)': 0.17,
#  'MCC': 0.19,
#  'Balanced accuracy': 0.7242063492063492,
#  'Classification Report': {'Non-Hypoglycemic': {'precision': 0.9850746268656716,
#    'recall': 0.6984126984126984,
#    'f1-score': 0.8173374613003096,
#    'support': 189},
#   'Hypoglycemic': {'precision': 0.09523809523809523,
#    'recall': 0.75,
#    'f1-score': 0.16901408450704225,
#    'support': 8},
#   'accuracy': 0.700507614213198,
#   'macro avg': {'precision': 0.5401563610518834,
#    'recall': 0.7242063492063492,
#    'f1-score': 0.4931757729036759,
#    'support': 197},
#   'weighted avg': {'precision': 0.9489391331955161,
#    'recall': 0.700507614213198,
#    'f1-score': 0.7910096084356084,
#    'support': 197}}}

# %% [markdown]
# **Mostramos las features ordenadas por importancia del modelo**

# %%
feature_importances = classifier.feature_importances_
feature_importance_df = pd.DataFrame({
    'Feature': selected_features,
    'Importance': feature_importances
})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

print(feature_importance_df.to_string(index=False))
# Out:
#             Feature  Importance
#                 cob    0.227700
#               basal    0.157599
#              aob_6h    0.156131
#       glucose_range    0.102230
#                 iob    0.083171
#         glucose_30m    0.077085
# total_bolus_squared    0.069217
# glucose_rate_change    0.055879
#          glucose_1h    0.044411
#                 cho    0.020848
#              aob_3h    0.005610
#                hour    0.000119
#             glucose    0.000000
#     mean_glucose_1h    0.000000
#        bolus_normal    0.000000
#            next_iob    0.000000

# %% [markdown]
# **Gráfica interpretabilidad general del modelo**

# %%
feature_importance_df = pd.DataFrame({
    'Feature': selected_features,
    'Importance': feature_importances
})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# **Interpretabilidad del grupo test por instancia y máscara**

# %%
explain_matrix, masks = classifier.explain(X_test.values)
n_steps = len(masks)
fig, axs = plt.subplots(1, n_steps, figsize=(20, 20))

for i in range(n_steps):
    axs[i].imshow(masks[i][:len(X_test.values)])
    axs[i].set_title(f"mask {i + 1}")
    axs[i].set_xticks(range(len(selected_features)))
    axs[i].set_xticklabels(labels=selected_features, rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretabilidad del grupo test agregada**

# %%
sum_of_features = None

# Sumar las importancias de las características de todas las máscaras
for mask in masks.values():
    if sum_of_features is None:
        sum_of_features = np.sum(mask, axis=0)
    else:
        sum_of_features += np.sum(mask, axis=0)

# Calcular el promedio dividiendo por el número total de máscaras
average_features = sum_of_features / len(masks)

# Ordenar las características y sus importancias promedio de mayor a menor
sorted_indices = np.argsort(average_features)[::-1]
sorted_features = np.array(selected_features)[sorted_indices]
sorted_importances = average_features[sorted_indices]

# Visualización con barras horizontales
plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_importances)), sorted_importances)
plt.yticks(range(len(sorted_importances)), sorted_features)
plt.title('Feature Importances')
plt.gca().invert_yaxis()  # Invertir el eje Y para que la característica más importante esté arriba
plt.show()
